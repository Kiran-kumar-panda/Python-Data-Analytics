# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/USER/Downloads/spotify-2023.csv',encoding='unicode_escape')
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.shape
# Out:
# (953, 24)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (817, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            817 non-null    object
#  1   artist(s)_name        817 non-null    object
#  2   artist_count          817 non-null    int64
#  3   released_year         817 non-null    int64
#  4   released_month        817 non-null    int64
#  5   released_day          817 non-null    int64
#  6   in_spotify_playlists  817 non-null    int64
#  7   in_spotify_charts     817 non-null    int64
#  8   streams               817 non-null    int64
#  9   in_apple_playlists    817 non-null    int64
#  10  in_apple_charts       817 non-null    int64
#  11  in_deezer_playlists   817 non-null    object
#  12  in_deezer_charts      817 non-null    int64
#  13  in_shazam_charts      817 non-null    object
#  14  bpm                   817 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
average_artist_per_track=df['artist_count'].mean()
average_artist_per_track
# Out:
# 1.5679314565483475

# %% [markdown]
# # Average artist per track
# The no of average artist per track is approx 1.56

# %%
# top 5 released year with no_of_songs released

# %%
a=df['released_year'].value_counts().head(5)
a
# Out:
# 2022    359
# 2023    159
# 2021     95
# 2019     27
# 2020     23
# Name: released_year, dtype: int64

# %% [markdown]
# # Top 5 years with no_of_songs released

# %%
year=[2022,2023,2021,2020,2019]
no_of_songs=[359,159,95,27,23]
data=pd.DataFrame({"year":year,"no_of_songs":no_of_songs})
ad=sns.barplot(x="year",y="no_of_songs",data=data)
plt.title("Top 5 years with no_of_songs released")
plt.show()

# %% [markdown]
# # from the above graph we find that Highest no_of_songs released in the year 2022

# %%
# top 5 months with no_of_songs
df['released_month']=df['released_month'].map({1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"June",7:"Jul",8:"Aug",9:"Sept"
                                               ,10:"Oct",11:"Nov",12:"Dec"})

# %%
df['released_month'].value_counts().head(5)
# Out:
# May     114
# Jan     113
# Mar      73
# June     73
# Dec      68
# Name: released_month, dtype: int64

# %%
x=["Jan","Mar","May","June","Nov"]
y=[113,73,114,73,68]
plt.plot(x,y,color="r")
plt.xlabel("months")
plt.ylabel("no_of-songs")
plt.title("top 5 most popular months with no_of_songs_released")
plt.show()

# %% [markdown]
# # Hence from above graph we conclude that maximum no_of_songs releases on Jan and may

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
# average danceability percentage
df['danceability_%'].mean()
# Out:
# 67.39167686658507

# %% [markdown]
# Average percent of danceabilty of those tracks is approx 67

# %%
mean1=df[df['released_year']==2019]['danceability_%'].mean()
mean2=df[df['released_year']==2020]['danceability_%'].mean()
mean3=df[df['released_year']==2021]['danceability_%'].mean()
mean4=df[df['released_year']==2022]['danceability_%'].mean()
mean5=df[df['released_year']==2023]['danceability_%'].mean()

# %%
l1=[mean1,mean2,mean3,mean4,mean5]
l2=[2019,2020,2021,2022,2023]
data=pd.DataFrame({"Year":l2,"Danceability_%":l1})
plt.figure(figsize=(10,6))
plt.xlabel('Year')
plt.ylabel('Danceability %')
plt.title("Last 5 years vs danceability %")

ax=sns.barplot(x=l2,y=l1,data=data)

# %% [markdown]
# # This is the percentage of danceability of last 5 years

# %% [markdown]
# Hence, we conclude from here that danceabilty percentage is increasing every year

# %%
# TRACK VS ACOUSTICNESS %

# %%
df_sorted = df.sort_values(by='acousticness_%', ascending=False)
df_sorted
top_5_tracks=df_sorted['track_name'].head(5)
top_5_tracks
# Out:
# 167        The Night We Met
# 587           Miserable Man
# 128    lovely - Bonus Track
# 691                 Forever
# 623               All of Me
# Name: track_name, dtype: object

# %%
df['acousticness_%'].sort_values(ascending=False).head(5)
# Out:
# 167    97
# 587    93
# 128    93
# 691    92
# 623    92
# Name: acousticness_%, dtype: int64

# %%
acousticness =[97,93,93,92,92]
top_5_tracks =["The Night We Met","Miserable Man","lovely - Bonus Track"," Forever","All of Me"]
data=pd.DataFrame({"top_5_tracks":top_5_tracks,"acousticness":acousticness})
plt.xticks(rotation=90)
plt.title("Top 5 tracks vs Acousticness_%")
sns.lineplot(x="top_5_tracks",y="acousticness",data=data)
# Out:
# <Axes: title={'center': 'Top 5 tracks vs Acousticness_%'}, xlabel='top_5_tracks', ylabel='acousticness'>

# %% [markdown]
# Here is the top 5 track name with most acousticness_%

# %%
df[['danceability_%','energy_%']].corr()
# Out:
#                 danceability_%  energy_%
# danceability_%         1.00000   0.15797
# energy_%               0.15797   1.00000

# %%
sns.regplot(x=df['danceability_%'],y=df["energy_%"],data=df)
plt.grid(True)

# %% [markdown]
# # There is no correlation between danceability_% and energy_%

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
t=df.groupby(['track_name'],as_index=False)['streams'].sum().sort_values(by='streams',ascending=False).head(10)

# %%
plt.figure(figsize=(12,4))
sns.barplot(x='track_name',y='streams',data=t)
plt.xticks(rotation=90)
plt.title("Top 10 tracks with highest streams")
plt.show()

# %% [markdown]
# # Above bargraph is the representation of top 10 track with maximum streams where we found "Shape of you" track lead in this list with more than 3562 million streams

# %%
sns.distplot(df['valence_%'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13520\174391265.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['valence_%'])
# <Axes: xlabel='valence_%', ylabel='Density'>

# %%
np.mean(df['valence_%'])
# Out:
# 51.201958384332926

# %%
np.median(df['valence_%'])
# Out:
# 51.0

# %% [markdown]
# "The distribution of valence percentages in the dataset appears to be positively skewed, with a peak around 60% valence. This suggests that a significant portion of the tracks have moderate valence values, while there are outliers with both very high and very low valence percentages. The distribution is relatively wide, indicating a diverse range of valence values in the dataset."

# %%
df.groupby(['artist(s)_name'],as_index=False)['streams'].sum().sort_values(by='streams',ascending=False).head(5)
# Out:
#     artist(s)_name      streams
# 491   Taylor Swift  11851151082
# 136     Ed Sheeran  11051252012
# 37       Bad Bunny   8582384095
# 145         Eminem   6183805596
# 505     The Weeknd   6038640754
